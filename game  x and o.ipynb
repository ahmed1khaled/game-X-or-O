# %%
broud={1:' ',2:' ',3:' ',
       4:' ',5:' ',6:' ',
       7:' ',8:' ',9:' '}
def drow(broud):
    print('-------------')
    print(': '+broud[1]+' | '+broud[2]+' | '+broud[3]+' :')
    print('-------------')
    print(': '+broud[4]+' | '+broud[5]+' | '+broud[6]+' :')
    print('-------------')
    print(': '+broud[7]+' | '+broud[8]+' | '+broud[9]+' :')
    print('-------------')
player2=''
while True:
    player1=input('enter x or o ==>')
    if player1=='x'or player1=='o':
        break
if player1=='x':
    player2+='o'
    print('==========')
    print('player1=> ',player1)
    print('========')
    print('player2=> ',player2)
    print('==========')
else:
    player2+='x'
    print('==========')
    print('player1=> ',player1)
    print('========')
    print('player2=> ',player2)
    print('==========')
op=[*range(1,10)]
for i in range(9):
    drow(broud)
    while True:
        print('empty places',op)
        if len(op)==1:
            player11=input(f'choice place player 1==> {player1} ==>')
            break
        else:
            player11=input(f'choice place player 1==> {player1} ==>')
            player22=input(f'choice place player 2==> {player2} ==>')
        if int(player11) in op and int(player22) in op :
            if int(player11)==int(player22):
                print('you mastnot repet the number you choice')
                continue
            else:
                break
        else:
            print('enter again')
    # becouse list op is empty when len(op)=0 show erroe try  and except skip this error
    try:
        op.remove(int(player11) )
        op.remove(int(player22))
        broud[int(player11)]=player1
        broud[int(player22)]=player2
    except:
        broud[int(player11)]=player1
        print('empty')
    if (broud[1]==broud[2]==broud[3]==player1)or(broud[1]==broud[4]==broud[7]==player1)or(broud[1]==broud[5]==broud[9]==player1)or(broud[4]==broud[5]==broud[6]==player1)or(broud[7]==broud[8]==broud[9]==player1)or(broud[7]==broud[5]==broud[3]==player1)or(broud[2]==broud[5]==broud[8]==player1):
        drow(broud)
        print(f'player1 => * {player1} * is win good luck player2 => * {player2} *')
        break
    elif (broud[1]==broud[2]==broud[3]==player2)or(broud[1]==broud[4]==broud[7]==player2)or(broud[1]==broud[5]==broud[9]==player2)or(broud[4]==broud[5]==broud[6]==player2)or(broud[7]==broud[8]==broud[9]==player2)or(broud[7]==broud[5]==broud[3]==player2)or(broud[2]==broud[5]==broud[8]==player2):
        drow(broud)
        print(f'player2 => * {player2} * is win good luck player1 => * {player1} *')
        break
    if len(op)==0 and (not((broud[1]==broud[2]==broud[3]==player1)or(broud[1]==broud[4]==broud[7]==player1)or(broud[1]==broud[5]==broud[9]==player1)or(broud[2]==broud[5]==broud[8]==player1))or not((broud[4]==broud[5]==broud[6]==player1)or(broud[7]==broud[8]==broud[9]==player1)or(broud[7]==broud[5]==broud[3]==player1)or(broud[1]==broud[2]==broud[3]==player2)or(broud[1]==broud[4]==broud[7]==player2)or(broud[1]==broud[5]==broud[9]==player2)or(broud[4]==broud[5]==broud[6]==player2)or(broud[7]==broud[8]==broud[9]==player2)or(broud[7]==broud[5]==broud[3]==player2)or(broud[2]==broud[5]==broud[8]==player2))):
        drow(broud)
        print('are not win')
        break
# Out:
# enter x or o ==>o
# ...
# player1=>  o
# ...
# player2=>  x
# ...
# -------------
# :   |   |   :
# -------------
# :   |   |   :
# -------------
# :   |   |   :
# -------------
# empty places [1, 2, 3, 4, 5, 6, 7, 8, 9]
# choice place player 1==> o ==>5
# choice place player 2==> x ==>6
# -------------
# :   |   |   :
# -------------
# :   | o | x :
# -------------
# :   |   |   :
# -------------
# empty places [1, 2, 3, 4, 7, 8, 9]
# choice place player 1==> o ==>8
# choice place player 2==> x ==>9
# -------------
# :   |   |   :
# -------------
# :   | o | x :
# -------------
# :   | o | x :
# -------------
# empty places [1, 2, 3, 4, 7]
# choice place player 1==> o ==>2
# choice place player 2==> x ==>4
# -------------
# :   | o |   :
# -------------
# : x | o | x :
# -------------
# :   | o | x :
# -------------
# player1 => * o * is win good luck player2 => * x *
